# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sns
import pandas as pd
from sklearn import metrics
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\abdal\\Downloads\\dataset.csv.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df["fbs"]=df["exang"].map({"yes": 1, "no": 0})
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0  NaN    1   3       145   233  NaN        0      150      0      2.3      0
# 1  NaN    1   2       130   250  NaN        1      187      0      3.5      0
# 2  NaN    0   1       130   204  NaN        0      172      0      1.4      2
# 3  NaN    1   1       120   236  NaN        1      178      0      0.8      2
# 4  NaN    0   0       120   354  NaN        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
from sklearn.linear_model import LogisticRegression
x = df[['age','chol','ca']]
y = df['cp']

x_train,x_test,y_train,y_test = train_test_split(x, y = 0.25,random_state=0)  

#logreg = LogisticRegression()   
#logreg.fit("x, y")  
#y_pred  = logreg.predict(x_test)    
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       2 x = df[['age','chol','ca']]
#       3 y = df['cp']
# ----> 5 x_train,x_test,y_train,y_test = train_test_split( 0.25,random_state=0)
#       7 #logreg = LogisticRegression()
#       8 #logreg.fit("x, y")
#       9 #y_pred  = logreg.predict(x_test)
#      10 print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
#
# File ~\anaconda2\lib\site-packages\sklearn\model_selection\_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# ...

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
#       2 sns.heatmap(confusion_matrix, annot=True)
#
# NameError: name 'y_pred' is not defined

# %%
ROC = np.random.binomial(1,.9,size = 1000)
AUC = np.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(ROC, AUC)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
#plt.show()
