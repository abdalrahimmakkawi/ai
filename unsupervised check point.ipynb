# %%
import pandas as pd
import numpy as np

# %%
df.isnull().sum()
# Out:
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0             0.166667                    0.000000
# 1             0.000000                    0.000000
# 2             1.000000                    1.000000
# 4             0.083333                    0.083333
# 5             0.666667                    0.000000
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                    0.00                 0
# 1                          0.000000                    0.25                 4
# 2                          0.000000                    0.00                 0
# 4                          0.000000                    0.00                 0
# 5                          0.583333                    0.00                 0
#
#    PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  \
# 0              2        1000.0   201.802084        139.509787
# ...

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\abdal\\Downloads\\CC GENERAL.csv")
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data=data.drop("CUST_ID", axis=1)
#data["BALANCE"]=data["BALANCE_FREQUENCY"] 
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(df, method="complete"))

# %%
plt.scatter(df["CASH_ADVANCE_FREQUENCY"][labels == 0],          
            df["PURCHASES_FREQUENCY"][data.label == 0],s=80,c='magenta',label='ONEOFF_PURCHASES')
plt.scatter(df["CASH_ADVANCE_FREQUENCY (k$)"][data.label == 1],
           df["PURCHASES_FREQUENCY (1-100)"][data.label == 1],s=80,c='yellow',label='ONEOFF_PURCHASES')
plt.scatter(df["CASH_ADVANCE_FREQUENCY (k$)"][data.label == 2],
           df["PURCHASES_FREQUENCY (1-100)"][data.label == 2],s=80,c='green',label='PURCHASES')
plt.scatter(df["CASH_ADVANCE_FREQUENCY (k$)"][data.label == 3], 
           data["PURCHASES_FREQUENCY (1-100)"][data.label == 3],s=80,c='cyan',label='BALANCE_FREQUENCY')
plt.scatter(df["CASH_ADVANCE_FREQUENCY (k$)"][data.label == 4], 
           df["PURCHASES_FREQUENCY (1-100)"][data.label == 4],s=80,c='burlywood',label='BALANCE')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'CASH_ADVANCE')
plt.title('PURCHASES_FREQUENCY')
plt.xlabel('CASH_ADVANCE_FREQUENCY(k$)')
plt.ylabel('PURCHASES_FREQUENCY(1-100')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 plt.scatter(df["CASH_ADVANCE_FREQUENCY"][labels == 0],
#       2             df["PURCHASES_FREQUENCY"][data.label == 0],s=80,c='magenta',label='ONEOFF_PURCHASES')
#       3 plt.scatter(df["CASH_ADVANCE_FREQUENCY (k$)"][data.label == 1],
#       4            df["PURCHASES_FREQUENCY (1-100)"][data.label == 1],s=80,c='yellow',label='ONEOFF_PURCHASES')
#       5 plt.scatter(df["CASH_ADVANCE_FREQUENCY (k$)"][data.label == 2],
#       6            df["PURCHASES_FREQUENCY (1-100)"][data.label == 2],s=80,c='green',label='PURCHASES')
#
# File ~\anaconda2\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# ...

# %%
data=pd.read_csv("C:\\Users\\abdal\\Downloads\\CC GENERAL.csv")

# %%
from sklearn.cluster import KMeans  
kmeans=KMeans(n_clusters=5, random_state=0)

# %%
kmeans.fit(df)
labels=pd.DataFrame(kmeans.labels_)
labels
# Out:
# C:\Users\abdal\anaconda2\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#       0
# 0     0
# 1     4
# 2     4
# 3     0
# 4     0
# ...  ..
# 8631  0
# 8632  0
# 8633  0
# 8634  0
# 8635  0
#
# [8636 rows x 1 columns]

# %%
df.head()
# Out:
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0             0.166667                    0.000000
# 1             0.000000                    0.000000
# 2             1.000000                    1.000000
# 4             0.083333                    0.083333
# 5             0.666667                    0.000000
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                    0.00                 0
# 1                          0.000000                    0.25                 4
# 2                          0.000000                    0.00                 0
# 4                          0.000000                    0.00                 0
# 5                          0.583333                    0.00                 0
#
#    PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  \
# 0              2        1000.0   201.802084        139.509787
# ...

# %%
kmeans.predict(df)
print(kmeans.cluster_centers_)
# Out:
# [[4.55165344e-01 1.33571403e-01 3.49049020e-01 1.14077083e-01
#   2.38715450e+00 9.72777888e+00 2.10500508e+03 9.08976602e+02
#   5.24914289e+02 1.48853036e-01 1.13799960e+01]
#  [5.91576103e-01 3.66468806e-01 4.19656025e-01 1.94652207e-01
#   5.17832957e+00 2.68442438e+01 1.20583008e+04 3.36315602e+03
#   1.36497698e+03 1.74015133e-01 1.17505643e+01]
#  [6.17555356e-01 4.53819115e-01 5.09232462e-01 2.99200769e-01
#   1.24615385e+01 6.67019231e+01 1.30798077e+04 2.04831891e+04
#   2.64095645e+03 2.91508788e-01 1.18076923e+01]
#  [4.70798873e-01 3.84297091e-02 4.41597818e-01 1.03030255e-01
#   3.01818182e+00 1.88363636e+01 4.26636364e+03 1.58459625e+03
#   2.29600155e+04 1.51514545e-03 1.19090909e+01]
#  [5.38709355e-01 2.85907539e-01 3.82787544e-01 1.58239993e-01
#   4.12334114e+00 1.91838407e+01 6.31854139e+03 2.20232195e+03
#   8.10895238e+02 1.72750402e-01 1.17435597e+01]]

# %%
what I see and noticed that the other plot is more specifically than the first plot
